# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
# %matplotlib inline
mnist_train = pd.read_csv("/content/sample_data/mnist_train_small.csv", header=None)
mnist_test = pd.read_csv("/content/sample_data/mnist_test.csv", header=None)
# Let's visualize the image represented by the first rows of the train data and the test data
train_data_digit1 = np.asarray(mnist_train.iloc[0:1,1:]).reshape(28,28)
test_data_digit1 = np.asarray(mnist_test.iloc[0:1,1:]).reshape(28,28)
plt.subplot(1,2,1)
plt.imshow(train_data_digit1,cmap = plt.cm.gray_r)
plt.title("First digit in train data")
plt.subplot(1,2,2)
plt.imshow(test_data_digit1,cmap = plt.cm.gray_r)
plt.title("First digit in test data ")
# Out:
# Text(0.5, 1.0, 'First digit in test data ')

# %%
X_train = mnist_train.iloc[:,1:]
Y_train = mnist_train.iloc[:,0:1]

# %%
from sklearn.neural_network import MLPClassifier
nn_model = MLPClassifier(hidden_layer_sizes=(50))
nn_model.fit(X_train,mnist_train.iloc[:,0])
print(nn_model.predict(mnist_test.iloc[0:1,1:]))
# Out:
# [7]

# %%
from sklearn.metrics import classification_report
# report based on train data
predicted_digit = nn_model.predict(X_train)
print(classification_report(Y_train,predicted_digit))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      1962
#            1       1.00      0.99      1.00      2243
#            2       0.99      0.97      0.98      1989
#            3       0.99      0.96      0.97      2021
#            4       0.99      0.98      0.99      1924
#            5       0.99      0.99      0.99      1761
#            6       0.99      0.99      0.99      2039
#            7       0.99      0.99      0.99      2126
#            8       0.92      1.00      0.96      1912
#            9       0.99      0.98      0.99      2023
#
#     accuracy                           0.98     20000
#    macro avg       0.99      0.99      0.98     20000
# weighted avg       0.99      0.98      0.99     20000
